# %% [markdown]
# <a href="https://colab.research.google.com/github/iyaja/IRIS-X/blob/master/(IRIS)_CamVid_Depth_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Image segmentation with CamVid

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID, dest="/content")
path.ls()
# Out:
# [PosixPath('/content/camvid/valid.txt'),
#  PosixPath('/content/camvid/images'),
#  PosixPath('/content/camvid/labels'),
#  PosixPath('/content/camvid/codes.txt')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/content/camvid/images/0001TP_008160_disp.jpeg'),
#  PosixPath('/content/camvid/images/0016E5_06870_disp.jpeg'),
#  PosixPath('/content/camvid/images/Seq05VD_f02370_disp.jpeg')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/content/camvid/labels/0001TP_009630_P.png'),
#  PosixPath('/content/camvid/labels/0016E5_08105_P.png'),
#  PosixPath('/content/camvid/labels/Seq05VD_f03540_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
#!/usr/bin/env python
import os
from glob import glob                                                           
import cv2 
pngs = glob('/content/camvid/images/*.png')

for j in pngs:
    img = cv2.imread(j)
    cv2.imwrite(j[:-3] + 'jpg', img)

# %%
# !git clone https://github.com/nianticlabs/monodepth2
# !cd monodepth2
# !python monodepth2/test_simple.py --image_path /content/camvid/images/ --model_name mono_1024x320
# Out:
# fatal: destination path 'monodepth2' already exists and is not an empty directory.
# -> Loading model from  models/mono_1024x320
#    Loading pretrained encoder
#    Loading pretrained decoder
# -> Predicting on 0 test images
# -> Done!

# %%
# !rm /content/camvid/images/*.png
# !rm /content/camvid/images/*.jpg
# Out:
# rm: cannot remove '/content/camvid/images/*.png': No such file or directory
# rm: cannot remove '/content/camvid/images/*.jpg': No such file or directory

# %%
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'.replace('_disp','').replace('.jpeg','.png')

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           ...,
#           [17, 17, 17,  ..., 30, 30, 30],
#           [17, 17, 17,  ..., 30, 30, 30],
#           [17, 17, 17,  ..., 30, 30, 30]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 11430MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_rand_pct(0.15)
       #.split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-4

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
lr_find(learn)
learn.recorder.plot()

# %%
lr=3e-3

# %%
learn.fit_one_cycle(5, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.510737</td>
#       <td>1.258725</td>
#       <td>0.615057</td>
#       <td>03:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.234543</td>
#       <td>1.380735</td>
#       <td>0.565687</td>
#       <td>03:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.278832</td>
#       <td>1.200213</td>
#       <td>0.655603</td>
#       <td>03:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.177398</td>
#       <td>1.057448</td>
#       <td>0.698837</td>
#       <td>03:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.090967</td>
#       <td>0.953021</td>
#       <td>0.720813</td>
#       <td>03:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.952283</td>
#       <td>0.914843</td>
#       <td>0.733427</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.928608</td>
#       <td>0.881294</td>
#       <td>0.749431</td>
#       <td>03:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.893855</td>
#       <td>0.833231</td>
#       <td>0.766361</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.873343</td>
#       <td>0.798581</td>
#       <td>0.777845</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.849603</td>
#       <td>0.775086</td>
#       <td>0.785619</td>
#       <td>03:34</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))
